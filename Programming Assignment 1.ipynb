# %%
# 1. Write a Python program to print "Hello Python"
print("Hello Python")
# Out:
# Hello Python

# %%
# 2. Write a Python program to do arithmetical operations addition and division.
num1, num2 = 10.52,5.21
print("%s + %s = %.2f" %(num1,num2,num1+num2)) # Addition
print("%s / %s = %.3f" %(num1,num2,num1/num2)) # Float division
print("%s / %s = %.3f" %(num1,num2,num1//num2)) #Floor division
# Out:
# 10.52 + 5.21 = 15.73
# 10.52 / 5.21 = 2.019
# 10.52 / 5.21 = 2.000

# %%
# 3. Write a Python program to find the area of a triangle
height = float(input("Enter height: "))
base = float(input("Enter base: "))
area = (height * base) / 2
print("Area of Triangle: %.2f" %(area))
# Out:
# Enter height: 12
# Enter base: 12
# Area of Triangle: 72.00

# %%
# 4. Write a Python program to swap two variables
var1 = 15
var2 = 30
print(var1, var2)

# Method 1 
var2, var1 = var1, var2
print(var1, var2)

# Method 2 - using temporary variable
temp = var1
var1 = var2
var2 = temp

print(var1,var2)
# Out:
# 15 30
# 30 15
# 15 30

# %%
# 5. Write a Python program to generate a random number
import random as r
print("Newly Generated Random Number is:", r.random()) # Random number between 0 and 1
print("Your lucky number is:", r.randint(1,100)) # Random number between given range
# Out:
# Newly Generated Random Number is: 0.7600300457583529
# Your lucky number is: 42
